# %%
from pathlib import Path
import pandas as pd

# %%
# raiz do projeto (WINOV)
ROOT = Path().resolve().parents[0]

# caminho dos dados brutos
RAW = ROOT / "data" / "raw"

# leitura do CSV (nome REAL do arquivo)
df = pd.read_csv(
    RAW / "banco_vendas_exemplo_teste.csv",
    sep=",",
    encoding="utf-8"
)

df.head()
# Out:
#    Codigo            DataVenda  CodFilial  CodCliente  \
# 0       1  2024-12-24 17:32:18         10        1010
# 1       2  2024-09-01 13:41:45         10        1010
# 2       3  2025-07-13 15:23:21         11        1155
# 3       4  2025-02-04 20:03:30         12        1254
# 4       5  2025-04-16 20:24:18         13        1315
#
#                                      NomeCliente  CidadeCliente EstadoCliente  \
# 0                   ASSOC. DAS PIONEIRAS SOCIAIS      São Paulo            SP
# 1                   ASSOC. DAS PIONEIRAS SOCIAIS      São Paulo            SP
# 2             HEMOCLIN CLINICA HEMATOLOGICA LTDA  Florianópolis            SC
# 3  EXLAB - LABORATORIO DE ANALISES CLINICAS LTDA        Goiânia            GO
# 4       LEMOS LAB. DE ANALISES CLINICAS S/S LTDA          Natal            RN
#
#    CodProduto DescricaoProdutos  CodVendedor     NomeVendedor  ValorBruto  \
# 0      951236     PORTA PALETE          4567   Camila Martins     5928.94
# ...

# %%
df.isnull().sum()
# Out:
# Codigo               0
# DataVenda            0
# CodFilial            0
# CodCliente           0
# NomeCliente          0
# CidadeCliente        0
# EstadoCliente        0
# CodProduto           0
# DescricaoProdutos    0
# CodVendedor          0
# NomeVendedor         0
# ValorBruto           0
# ValorLiquido         0
# Desconto             0
# Variação             0
# dtype: int64

# %%
df.shape
# Out:
# (1219, 15)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1219 entries, 0 to 1218
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Codigo             1219 non-null   int64
#  1   DataVenda          1219 non-null   str
#  2   CodFilial          1219 non-null   int64
#  3   CodCliente         1219 non-null   int64
#  4   NomeCliente        1219 non-null   str
#  5   CidadeCliente      1219 non-null   str
#  6   EstadoCliente      1219 non-null   str
#  7   CodProduto         1219 non-null   int64
#  8   DescricaoProdutos  1219 non-null   str
#  9   CodVendedor        1219 non-null   int64
#  10  NomeVendedor       1219 non-null   str
#  11  ValorBruto         1219 non-null   float64
#  12  ValorLiquido       1219 non-null   float64
#  13  Desconto           1219 non-null   float64
#  14  Variação           1219 non-null   float64
# dtypes: float64(4), int64(5), str(6)
# memory usage: 143.0 KB

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df[df.duplicated(keep=False)]
# Out:
#      Codigo            DataVenda  CodFilial  CodCliente  \
# 645     646  2025-04-09 10:30:31         23        2388
# 646     646  2025-04-09 10:30:31         23        2388
# 746     746  2024-08-22 02:09:17         18        1887
# 747     746  2024-08-22 02:09:17         18        1887
#
#                             NomeCliente CidadeCliente EstadoCliente  \
# 645  DIAFARMA PROD. P/LABORATORIOS LTDA     Fortaleza            CE
# 646  DIAFARMA PROD. P/LABORATORIOS LTDA     Fortaleza            CE
# 746                LABORCENTER FRANCAII   João Pessoa            PB
# 747                LABORCENTER FRANCAII   João Pessoa            PB
#
#      CodProduto DescricaoProdutos  CodVendedor     NomeVendedor  ValorBruto  \
# 645      258369        EIXO 48X48         1596  Mateus Carvalho     4038.92
# 646      258369        EIXO 48X48         1596  Mateus Carvalho     4038.92
# 746      123798        EIXO 24X48         2425  Bruno Rodrigues    13308.75
# ...

# %%
print("Antes:", df.shape)
df_clean = df.drop_duplicates()
print("Depois:", df_clean.shape)
# Out:
# Antes: (1219, 15)
# Depois: (1217, 15)

# %%
df_clean.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_processed = df_clean.copy()

df_processed.to_csv(
    ROOT / "data" / "processed" / "vendas_processed.csv",
    index=False
)
